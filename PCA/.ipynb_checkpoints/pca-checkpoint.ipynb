# %%
from numpy import array
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.naive_bayes import GaussianNB
import math
import sys
import copy

# %%
df=pd.read_csv("intrusion_detection/data.csv")

# %%
X = df.iloc[:,0:29].values
X = (X - X.mean())/X.std()
# X

# %%
meanvector = np.mean(X, axis=0)
m = X.shape[0]-1;
covariance = (X - meanvector).T.dot((X - meanvector))/m
# covariance

# %%
eigenvalue, eigenvector = np.linalg.eig(covariance)
eigen_val_vec = []
for i in range(len(eigenvector)):
    t = (np.abs(eigenvalue[i]),eigenvector[:,i])
    eigen_val_vec.append(t)

# eigenvector

# %%
eigen_val_vec.sort()
eigen_val_vec.reverse()
# eigen_val_vec

# %%
tot = sum(eigenvalue)
var_exp = [(i / tot)*100 for i in sorted(eigenvalue, reverse=True)]
# cum_var_exp = np.cumsum(var_exp)

# var_exp

# %%
lowerdimensionsmatrix = np.hstack((eigen_val_vec[0][1].reshape(29,1), 
                      eigen_val_vec[1][1].reshape(29,1)))
# matrix_w

# %%
X_low = X.dot(lowerdimensionsmatrix)
# X_low
# Out:
# array([[-1.35334514e-03,  1.72410906e-03],
#        [-1.61444095e-03,  1.72404034e-03],
#        [-1.72493368e-03,  1.72401128e-03],
#        ...,
#        [-3.64376607e-05,  1.43384458e-03],
#        [-1.72493368e-03,  1.72401128e-03],
#        [-1.61065696e-03,  1.72404135e-03]])

# %%
lower_df=pd.DataFrame(X_low)
# lower_df

# %%
df_final = pd.concat([lower_df,df['xAttack']],axis=1)
# df_final
# Out:
#                0         1 xAttack
# 0      -0.001353  0.001724  normal
# 1      -0.001614  0.001724  normal
# 2      -0.001725  0.001724     dos
# 3      -0.001548 -0.004446  normal
# 4      -0.001574  0.001406  normal
# 5      -0.001725  0.001724     dos
# 6      -0.001725  0.001724     dos
# 7      -0.001725  0.001724     dos
# 8      -0.001725  0.001724     dos
# 9      -0.001725  0.001724     dos
# 10     -0.001725  0.001724     dos
# 11     -0.001725  0.001724     dos
# 12     -0.001507  0.000021  normal
# 13     -0.001472  0.001724     r2l
# 14     -0.001725  0.001724     dos
# 15     -0.001725  0.001724     dos
# 16     -0.001495 -0.008711  normal
# 17     -0.001711  0.001724   probe
# 18     -0.001548  0.001258  normal
# 19     -0.001465  0.000833  normal
# 20     -0.001725  0.001724     dos
# 21     -0.001725  0.001724     dos
# 22     -0.001531 -0.007286  normal
# 23     -0.001614  0.001644  normal
# 24     -0.001725  0.001724     dos
# 25     -0.001391 -0.009190  normal
# 26     -0.001725  0.001724     dos
# 27     -0.001552 -0.003262  normal
# 28     -0.001560 -0.006222  normal
# 29     -0.001542  0.000665  normal
# ...          ...       ...     ...
# 125943 -0.001353  0.001724  normal
# 125944 -0.000174  0.001450  normal
# 125945 -0.001538  0.001119  normal
# 125946 -0.001725  0.001724     dos
# 125947 -0.001711  0.001724   probe
# 125948 -0.001725  0.001724     dos
# 125949 -0.001725  0.001724  normal
# 125950 -0.001704  0.001724     dos
# 125951 -0.001533  0.001304  normal
# 125952 -0.000749  0.001415  normal
# 125953 -0.001725  0.001724     dos
# 125954 -0.001519 -0.006555  normal
# 125955 -0.001725  0.001724  normal
# 125956 -0.001702  0.001724  normal
# 125957 -0.000781  0.001477  normal
# 125958 -0.001725  0.001724     dos
# 125959 -0.001442 -0.001891  normal
# 125960 -0.001476  0.001054  normal
# 125961 -0.001546 -0.000318  normal
# 125962 -0.001700  0.001724  normal
# 125963 -0.001472  0.000513  normal
# 125964 -0.001725  0.001724     dos
# 125965 -0.000035  0.001448  normal
# 125966 -0.001725  0.001724     dos
# 125967 -0.001453  0.001440  normal
# 125968 -0.001725  0.001724     dos
# 125969 -0.001645  0.001614  normal
# 125970 -0.000036  0.001434  normal
# 125971 -0.001725  0.001724     dos
# 125972 -0.001611  0.001724  normal
#
# [125973 rows x 3 columns]

# %%
import csv

with open('data1.csv', 'w') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerows(df_final)

csvFile.close()
